# %%
import os
from Loader import *

# %%
data_path=r'C:\Users\2chan\Desktop\data science project\twitch-highlight-predictor\data'
result_path=r'C:\Users\2chan\Desktop\data science project\twitch-highlight-predictor'
file_list=os.listdir(data_path)

# %%
###find specific line with user name and chat text

def find(text=None, usr=None):
    if(text != None and usr==None):
        for file in file_list:
            f=open(data_path+'//'+file, 'r', encoding='UTF8')
            for line in f:
                if(line.find(text)!=-1):
                    s=line.split(" ",2)
                    print(file[:-4], s[0][1:-1], s[1], s[2])
            f.close()
    elif(text==None and usr!=None):
        for file in file_list:
            f=open(data_path+'//'+file, 'r', encoding='UTF8')
            for line in f:
                if(line.find(usr)!=-1):
                    s=line.split(" ",2)
                    print(file[:-4], s[0], s[1][1:-1], s[2])
            f.close()
    elif(text != None and usr!= None):
        for file in file_list:
            f=open(data_path+'//'+file, 'r', encoding='UTF8')
            for line in f:
                if(line.find(text)!=-1 and line.find(usr)!=-1):
                    s=line.split(" ",2)
                    print(file[:-4], s[0], s[1][1:-1], s[2])
            f.close()
    else:
        print("something went wrong")

# %%
find(text='나 다시 돌아갈뢔애애')
# Out:
# 431933575 1:09:07 <파높파노> 나 다시 돌아갈뢔애애애애애애애!!

# %%
##total chat lines
total=0
for file in file_list:
    f=open(data_path+'//'+file, 'r', encoding='UTF8')
    for line in f:
        total+=1
print(total)
# Out:
# 5720257

# %%
##total streaming time
tot=0

for file in file_list:
    f=open(data_path+'//'+file, 'r', encoding='UTF8')
    time=f.readlines()[-1].split(' ')[0][1:-1].split(':')
    tot+=(int(time[0])*3600+int(time[1])*60+int(time[2]))
    

    print(tot)
# Out:
# 1986226

# %%
##analyzing part.

'''
1.Sensitivity : TP/(TP+FN)
2.Specificity : TN/(TN+FP)
3.Predictrive value positive: TP/(TP+FP)
4.Predictive value negative: TN/(TN+FN)
'''

def tn(TP, FP, FN):
    return 1986226/60 - (TP+FP+FN)

def Spe(line):
    line=line.split(', ')
    for a, word in enumerate(line):
        if word.find('FN:') != -1:
            FN=int(word[4:])
        if word.find('FP:') != -1:
            FP=int(word[4:])
        if word.find('TP:') != -1:
            TP=int(word[4:])
    TN=tn(TP, FP, FN)
    
    return TN/(TN+FP)

def Sen(line):
    line=line.split(', ')
    for a, word in enumerate(line):
        if word.find('TP:') != -1:
            TP=int(word[4:])
        if word.find('FN:') != -1:
            FN=int(word[4:])
    return TP/(TP+FN)

def PvP(line):
    line=line.split(', ')
    for a, word in enumerate(line):
        if word.find('TP:') != -1:
            TP=int(word[4:])
        if word.find('FP:') != -1:
            FP=int(word[4:])
    if(TP+FP==0):
        return 0
    else:
        return TP/(TP+FP)
def PvN(line):
    line=line.split(', ')
    for a, word in enumerate(line):
        if word.find('TP:') != -1:
            TP=int(word[4:])
        if word.find('FP:') != -1:
            FP=int(word[4:])
        if word.find('FN:') != -1:
            FN=int(word[4:])
    TN=tn(TP, FP , FN)
    
    return TN/(TN+FN)
    


result=open(result_path+'//result.txt', 'r')

lines=result.readlines()
lines.sort(key=Spe, reverse=True)
for line in lines:
    print(line[:-1])
# Out:
# burst, dur=1, thsld=20, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=30, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=3, thsld=50, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=60, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=40, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=60, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=40, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=3, thsld=60, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=4, thsld=60, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=50, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=50, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=80, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=4, thsld=70, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=80, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=5, thsld=70, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=3, thsld=80, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=4, thsld=80, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=70, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=5, thsld=80, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=70, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=6, thsld=80, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=3, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=3, thsld=70, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=4, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=5, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=6, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=3, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=7, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=4, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=5, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=6, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=7, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=8, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=1, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 0, TN: NaN, FN: 78
# rise, mov_av,window=100, step=10, TP: 0, FP: 0, TN: NaN, FN: 78
# burst, dur=2, thsld=30, words=ㅋㅋㅋ, TP: 0, FP: 1, TN: NaN, FN: 78
# burst, dur=9, thsld=100, words=ㅋㅋㅋ, TP: 0, FP: 1, TN: NaN, FN: 78
# rise, mov_av,window=70, step=10, TP: 0, FP: 2, TN: NaN, FN: 78
# trendy, dur=1, tsld=100, TP: 0, FP: 2, TN: NaN, FN: 78
# burst, dur=5, thsld=60, words=ㅋㅋㅋ, TP: 1, FP: 3, TN: NaN, FN: 77
# burst, dur=7, thsld=80, words=ㅋㅋㅋ, TP: 1, FP: 3, TN: NaN, FN: 77
# burst, dur=8, thsld=90, words=ㅋㅋㅋ, TP: 0, FP: 3, TN: NaN, FN: 78
# trendy, dur=1, tsld=90, TP: 0, FP: 3, TN: NaN, FN: 78
# trendy, dur=1, tsld=60, TP: 0, FP: 4, TN: NaN, FN: 78
# trendy, dur=1, tsld=80, TP: 0, FP: 4, TN: NaN, FN: 78
# trendy, dur=1, tsld=70, TP: 0, FP: 4, TN: NaN, FN: 78
# trendy, dur=2, tsld=100, TP: 0, FP: 4, TN: NaN, FN: 78
# rise, mov_av,window=100, step=9, TP: 1, FP: 4, TN: NaN, FN: 78
# burst, dur=6, thsld=70, words=ㅋㅋㅋ, TP: 0, FP: 5, TN: NaN, FN: 78
# rise, mov_av,window=50, step=10, TP: 0, FP: 5, TN: NaN, FN: 78
# burst, dur=4, thsld=50, words=ㅋㅋㅋ, TP: 1, FP: 6, TN: NaN, FN: 77
# burst, dur=3, thsld=40, words=ㅋㅋㅋ, TP: 0, FP: 6, TN: NaN, FN: 78
# burst, dur=10, thsld=100, words=ㅋㅋㅋ, TP: 1, FP: 6, TN: NaN, FN: 77
# trendy, dur=2, tsld=90, TP: 0, FP: 7, TN: NaN, FN: 78
# burst, dur=9, thsld=90, words=ㅋㅋㅋ, TP: 1, FP: 8, TN: NaN, FN: 77
# rise, mov_av,window=70, step=9, TP: 4, FP: 10, TN: NaN, FN: 74
# trendy, dur=1, tsld=50, TP: 0, FP: 10, TN: NaN, FN: 78
# trendy, dur=2, tsld=80, TP: 0, FP: 12, TN: NaN, FN: 78
# trendy, dur=3, tsld=100, TP: 0, FP: 12, TN: NaN, FN: 78
# burst, dur=8, thsld=80, words=ㅋㅋㅋ, TP: 1, FP: 14, TN: NaN, FN: 77
# rise, mov_av,window=100, step=8, TP: 5, FP: 14, TN: NaN, FN: 74
# trendy, dur=3, tsld=90, TP: 1, FP: 15, TN: NaN, FN: 77
# trendy, dur=2, tsld=70, TP: 1, FP: 16, TN: NaN, FN: 77
# trendy, dur=4, tsld=100, TP: 1, FP: 19, TN: NaN, FN: 77
# burst, dur=7, thsld=70, words=ㅋㅋㅋ, TP: 1, FP: 21, TN: NaN, FN: 77
# rise, mov_av,window=50, step=9, TP: 4, FP: 24, TN: NaN, FN: 74
# trendy, dur=3, tsld=80, TP: 2, FP: 24, TN: NaN, FN: 76
# trendy, dur=2, tsld=60, TP: 2, FP: 25, TN: NaN, FN: 76
# burst, dur=10, thsld=90, words=ㅋㅋㅋ, TP: 1, FP: 26, TN: NaN, FN: 77
# trendy, dur=4, tsld=90, TP: 2, FP: 30, TN: NaN, FN: 76
# rise, mov_av,window=30, step=10, TP: 5, FP: 31, TN: NaN, FN: 73
# trendy, dur=5, tsld=100, TP: 2, FP: 33, TN: NaN, FN: 76
# trendy, dur=1, tsld=40, TP: 2, FP: 35, TN: NaN, FN: 76
# trendy, dur=3, tsld=70, TP: 2, FP: 36, TN: NaN, FN: 76
# trendy, dur=4, tsld=80, TP: 3, FP: 40, TN: NaN, FN: 75
# rise, mov_av,window=70, step=8, TP: 7, FP: 42, TN: NaN, FN: 71
# burst, dur=6, thsld=60, words=ㅋㅋㅋ, TP: 2, FP: 46, TN: NaN, FN: 76
# burst, dur=9, thsld=80, words=ㅋㅋㅋ, TP: 4, FP: 47, TN: NaN, FN: 74
# trendy, dur=5, tsld=90, TP: 3, FP: 47, TN: NaN, FN: 75
# trendy, dur=6, tsld=100, TP: 2, FP: 51, TN: NaN, FN: 76
# trendy, dur=2, tsld=50, TP: 3, FP: 52, TN: NaN, FN: 75
# rise, mov_av,window=100, step=7, TP: 8, FP: 52, TN: NaN, FN: 71
# trendy, dur=3, tsld=60, TP: 3, FP: 55, TN: NaN, FN: 75
# trendy, dur=4, tsld=70, TP: 4, FP: 60, TN: NaN, FN: 74
# trendy, dur=7, tsld=100, TP: 3, FP: 64, TN: NaN, FN: 75
# trendy, dur=6, tsld=90, TP: 4, FP: 66, TN: NaN, FN: 74
# trendy, dur=5, tsld=80, TP: 3, FP: 67, TN: NaN, FN: 75
# trendy, dur=8, tsld=100, TP: 4, FP: 78, TN: NaN, FN: 74
# trendy, dur=7, tsld=90, TP: 5, FP: 80, TN: NaN, FN: 73
# burst, dur=8, thsld=70, words=ㅋㅋㅋ, TP: 6, FP: 82, TN: NaN, FN: 72
# trendy, dur=6, tsld=80, TP: 4, FP: 83, TN: NaN, FN: 74
# trendy, dur=5, tsld=70, TP: 6, FP: 85, TN: NaN, FN: 72
# burst, dur=10, thsld=80, words=ㅋㅋㅋ, TP: 9, FP: 87, TN: NaN, FN: 69
# trendy, dur=3, tsld=50, TP: 4, FP: 88, TN: NaN, FN: 74
# trendy, dur=4, tsld=60, TP: 5, FP: 90, TN: NaN, FN: 73
# trendy, dur=9, tsld=100, TP: 7, FP: 91, TN: NaN, FN: 71
# rise, mov_av,window=50, step=8, TP: 7, FP: 95, TN: NaN, FN: 71
# burst, dur=5, thsld=50, words=ㅋㅋㅋ, TP: 7, FP: 101, TN: NaN, FN: 71
# trendy, dur=1, tsld=30, TP: 4, FP: 102, TN: NaN, FN: 74
# trendy, dur=8, tsld=90, TP: 8, FP: 102, TN: NaN, FN: 70
# trendy, dur=2, tsld=40, TP: 8, FP: 104, TN: NaN, FN: 70
# trendy, dur=10, tsld=100, TP: 8, FP: 106, TN: NaN, FN: 70
# trendy, dur=7, tsld=80, TP: 7, FP: 109, TN: NaN, FN: 71
# trendy, dur=9, tsld=90, TP: 9, FP: 115, TN: NaN, FN: 69
# trendy, dur=6, tsld=70, TP: 7, FP: 120, TN: NaN, FN: 71
# trendy, dur=8, tsld=80, TP: 10, FP: 126, TN: NaN, FN: 68
# trendy, dur=5, tsld=60, TP: 9, FP: 133, TN: NaN, FN: 69
# trendy, dur=10, tsld=90, TP: 10, FP: 136, TN: NaN, FN: 68
# trendy, dur=4, tsld=50, TP: 9, FP: 141, TN: NaN, FN: 69
# trendy, dur=7, tsld=70, TP: 9, FP: 145, TN: NaN, FN: 69
# rise, mov_av,window=30, step=9, TP: 7, FP: 146, TN: NaN, FN: 72
# trendy, dur=9, tsld=80, TP: 10, FP: 148, TN: NaN, FN: 68
# rise, mov_av,window=70, step=7, TP: 12, FP: 151, TN: NaN, FN: 66
# rise, mov_av,window=100, step=6, TP: 14, FP: 151, TN: NaN, FN: 65
# trendy, dur=3, tsld=40, TP: 10, FP: 163, TN: NaN, FN: 68
# trendy, dur=10, tsld=80, TP: 11, FP: 170, TN: NaN, FN: 67
# burst, dur=7, thsld=60, words=ㅋㅋㅋ, TP: 14, FP: 172, TN: NaN, FN: 64
# trendy, dur=6, tsld=60, TP: 9, FP: 173, TN: NaN, FN: 69
# trendy, dur=8, tsld=70, TP: 10, FP: 174, TN: NaN, FN: 68
# burst, dur=9, thsld=70, words=ㅋㅋㅋ, TP: 17, FP: 183, TN: NaN, FN: 61
# burst, dur=4, thsld=40, words=ㅋㅋㅋ, TP: 12, FP: 186, TN: NaN, FN: 66
# trendy, dur=5, tsld=50, TP: 10, FP: 199, TN: NaN, FN: 68
# trendy, dur=9, tsld=70, TP: 13, FP: 204, TN: NaN, FN: 65
# trendy, dur=7, tsld=60, TP: 10, FP: 216, TN: NaN, FN: 68
# trendy, dur=2, tsld=30, TP: 11, FP: 219, TN: NaN, FN: 67
# trendy, dur=10, tsld=70, TP: 13, FP: 237, TN: NaN, FN: 65
# trendy, dur=8, tsld=60, TP: 12, FP: 248, TN: NaN, FN: 66
# trendy, dur=4, tsld=40, TP: 11, FP: 257, TN: NaN, FN: 67
# trendy, dur=6, tsld=50, TP: 10, FP: 260, TN: NaN, FN: 68
# trendy, dur=9, tsld=60, TP: 13, FP: 287, TN: NaN, FN: 65
# rise, mov_av,window=50, step=7, TP: 19, FP: 293, TN: NaN, FN: 60
# burst, dur=10, thsld=70, words=ㅋㅋㅋ, TP: 21, FP: 296, TN: NaN, FN: 57
# trendy, dur=7, tsld=50, TP: 14, FP: 313, TN: NaN, FN: 64
# burst, dur=6, thsld=50, words=ㅋㅋㅋ, TP: 24, FP: 322, TN: NaN, FN: 54
# trendy, dur=1, tsld=20, TP: 13, FP: 323, TN: NaN, FN: 65
# trendy, dur=5, tsld=40, TP: 13, FP: 327, TN: NaN, FN: 65
# burst, dur=8, thsld=60, words=ㅋㅋㅋ, TP: 23, FP: 328, TN: NaN, FN: 55
# trendy, dur=10, tsld=60, TP: 14, FP: 330, TN: NaN, FN: 64
# burst, dur=3, thsld=30, words=ㅋㅋㅋ, TP: 22, FP: 344, TN: NaN, FN: 56
# rise, mov_av,window=70, step=6, TP: 22, FP: 344, TN: NaN, FN: 57
# rise, mov_av,window=10, step=10, TP: 13, FP: 358, TN: NaN, FN: 65
# trendy, dur=3, tsld=30, TP: 13, FP: 359, TN: NaN, FN: 65
# trendy, dur=8, tsld=50, TP: 16, FP: 381, TN: NaN, FN: 62
# rise, mov_av,window=30, step=8, TP: 14, FP: 394, TN: NaN, FN: 65
# rise, mov_av,window=100, step=5, TP: 30, FP: 420, TN: NaN, FN: 49
# trendy, dur=6, tsld=40, TP: 15, FP: 433, TN: NaN, FN: 63
# trendy, dur=9, tsld=50, TP: 15, FP: 440, TN: NaN, FN: 63
# trendy, dur=10, tsld=50, TP: 16, FP: 497, TN: NaN, FN: 62
# trendy, dur=4, tsld=30, TP: 14, FP: 525, TN: NaN, FN: 64
# trendy, dur=7, tsld=40, TP: 15, FP: 529, TN: NaN, FN: 63
# burst, dur=9, thsld=60, words=ㅋㅋㅋ, TP: 26, FP: 530, TN: NaN, FN: 52
# burst, dur=7, thsld=50, words=ㅋㅋㅋ, TP: 29, FP: 621, TN: NaN, FN: 49
# trendy, dur=8, tsld=40, TP: 17, FP: 636, TN: NaN, FN: 61
# burst, dur=5, thsld=40, words=ㅋㅋㅋ, TP: 31, FP: 643, TN: NaN, FN: 47
# trendy, dur=2, tsld=20, TP: 16, FP: 675, TN: NaN, FN: 62
# burst, dur=10, thsld=60, words=ㅋㅋㅋ, TP: 28, FP: 712, TN: NaN, FN: 50
# rise, mov_av,window=50, step=6, TP: 25, FP: 716, TN: NaN, FN: 54
# trendy, dur=5, tsld=30, TP: 17, FP: 720, TN: NaN, FN: 61
# trendy, dur=9, tsld=40, TP: 19, FP: 731, TN: NaN, FN: 59
# rise, mov_av,window=70, step=5, TP: 37, FP: 774, TN: NaN, FN: 42
# burst, dur=2, thsld=20, words=ㅋㅋㅋ, TP: 30, FP: 814, TN: NaN, FN: 48
# trendy, dur=10, tsld=40, TP: 18, FP: 828, TN: NaN, FN: 60
# burst, dur=8, thsld=50, words=ㅋㅋㅋ, TP: 34, FP: 909, TN: NaN, FN: 45
# rise, mov_av,window=30, step=7, TP: 28, FP: 918, TN: NaN, FN: 51
# trendy, dur=6, tsld=30, TP: 18, FP: 933, TN: NaN, FN: 60
# rise, mov_av,window=100, step=4, TP: 41, FP: 996, TN: NaN, FN: 38
# rise, mov_av,window=10, step=9, TP: 21, FP: 1070, TN: NaN, FN: 57
# burst, dur=6, thsld=40, words=ㅋㅋㅋ, TP: 33, FP: 1073, TN: NaN, FN: 45
# trendy, dur=3, tsld=20, TP: 19, FP: 1115, TN: NaN, FN: 59
# trendy, dur=7, tsld=30, TP: 19, FP: 1125, TN: NaN, FN: 59
# burst, dur=4, thsld=30, words=ㅋㅋㅋ, TP: 37, FP: 1139, TN: NaN, FN: 41
# burst, dur=9, thsld=50, words=ㅋㅋㅋ, TP: 37, FP: 1163, TN: NaN, FN: 42
# trendy, dur=8, tsld=30, TP: 20, FP: 1315, TN: NaN, FN: 59
# burst, dur=10, thsld=50, words=ㅋㅋㅋ, TP: 39, FP: 1410, TN: NaN, FN: 40
# burst, dur=7, thsld=40, words=ㅋㅋㅋ, TP: 40, FP: 1483, TN: NaN, FN: 39
# rise, mov_av,window=10, step=1, TP: 6, FP: 1495, TN: NaN, FN: 72
# trendy, dur=9, tsld=30, TP: 22, FP: 1495, TN: NaN, FN: 57
# rise, mov_av,window=50, step=5, TP: 41, FP: 1507, TN: NaN, FN: 38
# trendy, dur=10, tsld=30, TP: 24, FP: 1632, TN: NaN, FN: 55
# trendy, dur=4, tsld=20, TP: 25, FP: 1633, TN: NaN, FN: 53
# burst, dur=1, thsld=10, words=ㅋㅋㅋ, TP: 42, FP: 1708, TN: NaN, FN: 37
# rise, mov_av,window=70, step=4, TP: 44, FP: 1744, TN: NaN, FN: 35
# rise, mov_av,window=30, step=6, TP: 35, FP: 1824, TN: NaN, FN: 44
# burst, dur=8, thsld=40, words=ㅋㅋㅋ, TP: 42, FP: 1860, TN: NaN, FN: 37
# burst, dur=5, thsld=30, words=ㅋㅋㅋ, TP: 38, FP: 1875, TN: NaN, FN: 41
# trendy, dur=5, tsld=20, TP: 26, FP: 2151, TN: NaN, FN: 52
# burst, dur=9, thsld=40, words=ㅋㅋㅋ, TP: 36, FP: 2200, TN: NaN, FN: 43
# burst, dur=3, thsld=20, words=ㅋㅋㅋ, TP: 42, FP: 2204, TN: NaN, FN: 37
# rise, mov_av,window=10, step=8, TP: 31, FP: 2407, TN: NaN, FN: 48
# rise, mov_av,window=100, step=3, TP: 46, FP: 2413, TN: NaN, FN: 33
# burst, dur=10, thsld=40, words=ㅋㅋㅋ, TP: 37, FP: 2460, TN: NaN, FN: 42
# burst, dur=6, thsld=30, words=ㅋㅋㅋ, TP: 39, FP: 2519, TN: NaN, FN: 40
# trendy, dur=6, tsld=20, TP: 25, FP: 2614, TN: NaN, FN: 53
# burst, dur=7, thsld=30, words=ㅋㅋㅋ, TP: 39, FP: 3016, TN: NaN, FN: 40
# trendy, dur=7, tsld=20, TP: 28, FP: 3023, TN: NaN, FN: 51
# trendy, dur=1, tsld=10, TP: 45, FP: 3068, TN: NaN, FN: 34
# rise, mov_av,window=50, step=4, TP: 54, FP: 3079, TN: NaN, FN: 25
# burst, dur=4, thsld=20, words=ㅋㅋㅋ, TP: 38, FP: 3390, TN: NaN, FN: 41
# rise, mov_av,window=30, step=5, TP: 50, FP: 3396, TN: NaN, FN: 29
# trendy, dur=8, tsld=20, TP: 30, FP: 3396, TN: NaN, FN: 49
# burst, dur=8, thsld=30, words=ㅋㅋㅋ, TP: 37, FP: 3409, TN: NaN, FN: 42
# trendy, dur=9, tsld=20, TP: 31, FP: 3647, TN: NaN, FN: 48
# burst, dur=9, thsld=30, words=ㅋㅋㅋ, TP: 37, FP: 3728, TN: NaN, FN: 42
# trendy, dur=10, tsld=20, TP: 31, FP: 3876, TN: NaN, FN: 48
# rise, mov_av,window=70, step=3, TP: 55, FP: 3890, TN: NaN, FN: 24
# burst, dur=10, thsld=30, words=ㅋㅋㅋ, TP: 37, FP: 3997, TN: NaN, FN: 42
# rise, mov_av,window=10, step=7, TP: 39, FP: 4236, TN: NaN, FN: 40
# burst, dur=5, thsld=20, words=ㅋㅋㅋ, TP: 39, FP: 4242, TN: NaN, FN: 40
# burst, dur=6, thsld=20, words=ㅋㅋㅋ, TP: 39, FP: 4785, TN: NaN, FN: 40
# trendy, dur=2, tsld=10, TP: 52, FP: 4811, TN: NaN, FN: 27
# burst, dur=2, thsld=10, words=ㅋㅋㅋ, TP: 41, FP: 4819, TN: NaN, FN: 38
# burst, dur=7, thsld=20, words=ㅋㅋㅋ, TP: 37, FP: 5243, TN: NaN, FN: 42
# burst, dur=8, thsld=20, words=ㅋㅋㅋ, TP: 37, FP: 5550, TN: NaN, FN: 42
# rise, mov_av,window=100, step=2, TP: 67, FP: 5605, TN: NaN, FN: 12
# rise, mov_av,window=30, step=4, TP: 62, FP: 5768, TN: NaN, FN: 17
# burst, dur=9, thsld=20, words=ㅋㅋㅋ, TP: 36, FP: 5802, TN: NaN, FN: 43
# rise, mov_av,window=50, step=3, TP: 64, FP: 5845, TN: NaN, FN: 15
# burst, dur=10, thsld=20, words=ㅋㅋㅋ, TP: 32, FP: 6025, TN: NaN, FN: 47
# trendy, dur=3, tsld=10, TP: 44, FP: 6105, TN: NaN, FN: 35
# rise, mov_av,window=10, step=6, TP: 52, FP: 6373, TN: NaN, FN: 27
# burst, dur=3, thsld=10, words=ㅋㅋㅋ, TP: 37, FP: 6378, TN: NaN, FN: 42
# trendy, dur=4, tsld=10, TP: 37, FP: 7023, TN: NaN, FN: 42
# burst, dur=4, thsld=10, words=ㅋㅋㅋ, TP: 35, FP: 7189, TN: NaN, FN: 44
# rise, mov_av,window=10, step=2, TP: 19, FP: 7586, TN: NaN, FN: 60
# trendy, dur=5, tsld=10, TP: 36, FP: 7597, TN: NaN, FN: 43
# burst, dur=5, thsld=10, words=ㅋㅋㅋ, TP: 27, FP: 7611, TN: NaN, FN: 52
# rise, mov_av,window=70, step=2, TP: 67, FP: 7635, TN: NaN, FN: 12
# burst, dur=10, thsld=10, words=ㅋㅋㅋ, TP: 17, FP: 7655, TN: NaN, FN: 61
# burst, dur=9, thsld=10, words=ㅋㅋㅋ, TP: 20, FP: 7709, TN: NaN, FN: 58
# burst, dur=6, thsld=10, words=ㅋㅋㅋ, TP: 25, FP: 7740, TN: NaN, FN: 54
# burst, dur=8, thsld=10, words=ㅋㅋㅋ, TP: 20, FP: 7783, TN: NaN, FN: 58
# burst, dur=7, thsld=10, words=ㅋㅋㅋ, TP: 21, FP: 7787, TN: NaN, FN: 57
# rise, mov_av,window=30, step=1, TP: 26, FP: 7937, TN: NaN, FN: 53
# trendy, dur=6, tsld=10, TP: 31, FP: 7958, TN: NaN, FN: 48
# trendy, dur=7, tsld=10, TP: 30, FP: 8143, TN: NaN, FN: 49
# trendy, dur=10, tsld=10, TP: 24, FP: 8164, TN: NaN, FN: 55
# trendy, dur=9, tsld=10, TP: 24, FP: 8211, TN: NaN, FN: 55
# trendy, dur=8, tsld=10, TP: 28, FP: 8213, TN: NaN, FN: 51
# rise, mov_av,window=10, step=5, TP: 59, FP: 8427, TN: NaN, FN: 20
# rise, mov_av,window=30, step=3, TP: 66, FP: 9037, TN: NaN, FN: 13
# rise, mov_av,window=50, step=2, TP: 71, FP: 10157, TN: NaN, FN: 8
# rise, mov_av,window=10, step=4, TP: 65, FP: 10179, TN: NaN, FN: 14
# rise, mov_av,window=10, step=3, TP: 47, FP: 10487, TN: NaN, FN: 32
# rise, mov_av,window=100, step=1, TP: 64, FP: 10540, TN: NaN, FN: 15
# rise, mov_av,window=70, step=1, TP: 53, FP: 11009, TN: NaN, FN: 26
# rise, mov_av,window=50, step=1, TP: 45, FP: 11578, TN: NaN, FN: 34
# rise, mov_av,window=30, step=2, TP: 62, FP: 12200, TN: NaN, FN: 17
